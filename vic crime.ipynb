# %%
import pandas as pd
# !pip install openpyxl

excel_file = 'Data_Tables_LGA_Criminal_Incidents_Year_Ending_March_2022.xlsx'
all_sheets = pd.read_excel(excel_file, sheet_name=None)
sheets = all_sheets.keys()

for sheet_name in sheets:
    sheet = pd.read_excel(excel_file, sheet_name=sheet_name)
    sheet.to_csv("%s.csv" % sheet_name, index=False)
# Out:
# Requirement already satisfied: openpyxl in /Users/juliacooper/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages (3.0.10)
# Requirement already satisfied: et-xmlfile in /Users/juliacooper/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages (from openpyxl) (1.1.0)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/h4/302vnt9j1kb09wlh6m55qbt40000gn/T/ipykernel_58074/1889137823.py in <module>
#       3
#       4 excel_file = 'Data_Tables_LGA_Criminal_Incidents_Year_Ending_March_2022.xlsx'
# ----> 5 all_sheets = pd.read_excel(excel_file, sheet_name=None)
#       6 sheets = all_sheets.keys()
#       7
#
# ~/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
#     363         should_close = True
# --> 364         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365     elif engine and engine != io.engine:
#     366         raise ValueError(
#
# ~/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1190             else:
#    1191                 ext = inspect_excel_format(
# -> 1192                     content_or_path=path_or_buffer, storage_options=storage_options
#    1193                 )
#    1194                 if ext is None:
#
# ~/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1069
#    1070     with get_handle(
# -> 1071         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072     ) as handle:
#    1073         stream = handle.handle
#
# ~/opt/anaconda3/envs/bootcamp/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Data_Tables_LGA_Criminal_Incidents_Year_Ending_March_2022.xlsx'

# %% [markdown]
# Contents
# Table 01
#
# * Criminal incidents and rate per 100,000 population by police region and local government area - April 2012 to March 2022
#
# Table 02
#
# * Criminal incidents and rate per 100,000 population by principal offence, local government area and police service area - April 2012 to March 2022
#
# Table 03
#
# * Criminal incidents by principal offence, local government area and postcode or suburb/town - April 2012 to March 2022
#
# Table 04
#
# * Criminal incidents by location type and local government area - April 2012 to March 2022
#
# Table 05
#
# * Criminal incidents by charge status and local government area - April 2012 to March 2022
#
# ### Data exclusions
# Table 01
#
# * excludes criminal incidents where the geographic location is unknown. For further information of these geographic locations please refer to the Explanatory Notes and Glossary on the website.
#
# Tables 02 - 05
#
# * excludes criminal incidents at Justice institutions and immigration facilities, Unincorporated Victoria and where the geographic location is unknown. For further information of these geographic locations please refer to the Explanatory Notes and Glossary on the website.
#
# Notes
# Recorded crime statistics are based on data extracted by Victoria police on the 18th day after the reference period, and are subject to movement between releases. For more information about how statistics are compiled, refer to the Explanatory notes on the CSA website.
# In order to maintain confidentiality, sensitive offence counts for subdivisions 'A10 Homicide and related offences' and 'A30 Sexual offences' with a value of 3 or less are given a value of 2 to calculate totals.
# Rates are based on populations provided by the Australian Bureau of Statistics (ABS). The most recent year of data was not available from the ABS in time for it to be used to calculate current year rates. The CSA uses estimates created by the Victorian State Government 'Victoria in Futures' report.
# This work is licenced under a Creative Commons Attribution 4.0 International License. When reporting this data you must attribute the Crime Statistics Agency (or CSA) as the source.

# %%
#Create list of dataframes from csv files
file_list = []
for i in range(1,6):
    file_list.append(f"Table 0{i}.csv")

# df_list = [pd.read_csv(file) for file in file_list]

# %%
file_list
# Out:
# ['Table 01.csv',
#  'Table 02.csv',
#  'Table 03.csv',
#  'Table 04.csv',
#  'Table 05.csv']

# %%
import pandas as pd
df_list = [pd.read_csv(file) for file in file_list]

# %%
df_list[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 870 entries, 0 to 869
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         870 non-null    int64
#  1   Year ending                  870 non-null    object
#  2   Police Region                870 non-null    object
#  3   Local Government Area        870 non-null    object
#  4   Incidents Recorded           870 non-null    int64
#  5   Rate per 100,000 population  830 non-null    float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 40.9+ KB

# %%
# df_list[0]['Date'] = df_list[0][]

police_region_df = df_list[0].loc[df_list[0].Year > 2018].drop('Year ending',axis=1)
police_region_df.head()
# Out:
#    Year       Police Region Local Government Area  Incidents Recorded  \
# 0  2022  1 North West Metro               Banyule                5244
# 1  2022  1 North West Metro              Brimbank               12330
# 2  2022  1 North West Metro               Darebin                9276
# 3  2022  1 North West Metro           Hobsons Bay                4599
# 4  2022  1 North West Metro                  Hume               12196
#
#    Rate per 100,000 population
# 0                  4086.865525
# 1                  6200.959480
# 2                  5751.475727
# 3                  4804.896128
# 4                  4919.684615

# %%
police_division_df = df_list[1].loc[df_list[1].Year > 2018].drop('Year ending',axis=1)
police_division_df.head()
# Out:
#    Year Police Service Area Local Government Area  \
# 0  2022            Ballarat              Ballarat
# 1  2022            Ballarat              Ballarat
# 2  2022            Ballarat              Ballarat
# 3  2022            Ballarat              Ballarat
# 4  2022            Ballarat              Ballarat
#
#               Offence Division                Offence Subdivision  \
# 0  A Crimes against the person  A10 Homicide and related offences
# 1  A Crimes against the person   A20 Assault and related offences
# 2  A Crimes against the person   A20 Assault and related offences
# 3  A Crimes against the person   A20 Assault and related offences
# 4  A Crimes against the person   A20 Assault and related offences
#
#                                     Offence Subgroup  Incidents Recorded  \
# 0                  A10 Homicide and related offences                   5
# 1                            A211 FV Serious assault                 120
# 2                        A212 Non-FV Serious assault                 147
# 3  A22 Assault police, emergency services or othe...                  53
# 4                             A231 FV Common assault                 222
#
#    PSA Rate per 100,000 population  LGA Rate per 100,000 population
# 0                         4.059101                         4.328089
# 1                        97.418429                       103.874128
# 2                       119.337575                       127.245807
# 3                        43.026473                        45.877740
# 4                       180.224093                       192.167137

# %%
suburb = df_list[2].loc[df_list[2].Year > 2018].drop('Year ending',axis=1)
suburb.head()
# Out:
#    Year Local Government Area  Postcode Suburb/Town Name  \
# 0  2022                Alpine      3691         Dederang
# 1  2022                Alpine      3691         Dederang
# 2  2022                Alpine      3691         Dederang
# 3  2022                Alpine      3691         Dederang
# 4  2022                Alpine      3691  Kergunyah South
#
#                        Offence Division                   Offence Subdivision  \
# 0           A Crimes against the person       Other crimes against the person
# 1     B Property and deception offences          B30 Burglary/Break and enter
# 2     B Property and deception offences                         B50 Deception
# 3  D Public order and security offences  D20 Disorderly and offensive conduct
# 4         E Justice procedures offences                E10 Justice procedures
#
#                                     Offence Subgroup  Incidents Recorded
# 0                    Other crimes against the person                   2
# 1           B321 Residential non-aggravated burglary                   1
# 2                    B53 Obtain benefit by deception                   1
# 3                 D22 Drunk and disorderly in public                   1
# 4  E14 Pervert the course of justice or commit pe...                   1

# %%
df_list[3]
# Out:
#        Year Year ending Local Government Area Location Division  \
# 0      2022       March                Alpine     1 Residential
# 1      2022       March                Alpine     1 Residential
# 2      2022       March                Alpine     1 Residential
# 3      2022       March                Alpine     1 Residential
# 4      2022       March                Alpine     1 Residential
# ...     ...         ...                   ...               ...
# 53350  2013       March          Yarriambiack           3 Other
# 53351  2013       March          Yarriambiack           3 Other
# 53352  2013       March          Yarriambiack           3 Other
# 53353  2013       March          Yarriambiack           3 Other
# 53354  2013       March          Yarriambiack           3 Other
#
#         Location Subdivision                      Location Group  \
# 0      11 Dwelling - private             111 Flat/Unit/Apartment
# 1      11 Dwelling - private                           112 House
# 2      11 Dwelling - private             114 Caravan/Mobile Home
# 3      11 Dwelling - private             116 Ministry Of Housing
# 4      11 Dwelling - private                      117 Farm House
# ...                      ...                                 ...
# 53350        37 Agricultural           371 Farmland/Agricultural
# 53351        38 Recreational               381 Licensed Premises
# 53352        38 Recreational             384 Sport Area/Facility
# 53353        38 Recreational               386 Other Rec./Sports
# 53354      39 Other location  392 Other Location (Not Elsewhere)
#
#        Incidents Recorded
# 0                       4
# 1                     118
# 2                       3
# 3                       1
# 4                       4
# ...                   ...
# 53350                   5
# 53351                   2
# 53352                   3
# 53353                   3
# 53354                   4
#
# [53355 rows x 7 columns]

# %%
df_list[4]
# Out:
#       Year Year ending Local Government Area    Charge Status  \
# 0     2022       March                Alpine     Charges laid
# 1     2022       March                Alpine  No charges laid
# 2     2022       March                Alpine         Unsolved
# 3     2022       March                Ararat     Charges laid
# 4     2022       March                Ararat  No charges laid
# ...    ...         ...                   ...              ...
# 2365  2013       March          Yarra Ranges  No charges laid
# 2366  2013       March          Yarra Ranges         Unsolved
# 2367  2013       March          Yarriambiack     Charges laid
# 2368  2013       March          Yarriambiack  No charges laid
# 2369  2013       March          Yarriambiack         Unsolved
#
#       Incidents Recorded
# 0                    149
# 1                    114
# 2                    108
# 3                    467
# 4                    217
# ...                  ...
# 2365                 792
# 2366                2614
# 2367                 127
# 2368                  53
# 2369                  85
#
# [2370 rows x 5 columns]
