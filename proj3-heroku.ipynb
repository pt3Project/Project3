# %%
#Character, Hair Color, Height, Football Head
connection = 'postgresql://dzvvuadeabjykv:52e20e27a11369714177a77897b26b72f75c29f0320ee9b3114a7b21c5a4edd4@ec2-34-199-68-114.compute-1.amazonaws.com:5432/ddthf1b3u3h6eu'

# %%
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine


engine = create_engine(connection)

# %%
data =  engine.execute("SELECT * FROM public.mytable;")
    
for record in data:
    print(record)
# Out:
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '1 North West Metro')
# (2022, 'March', '2 Eastern')
# (2022, 'March', '2 Eastern')
# (2022, 'March', '2 Eastern')
# (2022, 'March', '2 Eastern')
# (2022, 'March', '2 Eastern')
# (2022, 'March', '2 Eastern')
# (2022, 'March', '2 Eastern')
# (2022, 'March', '2 Eastern')
# (2022, 'March', '2 Eastern')
# (2022, 'March', '2 Eastern')
# (2022, 'March', '2 Eastern')
# (2022, 'March', '2 Eastern')
# ...

# %%
import pandas as pd
pd.read_sql(engine,'SELECT * FROM public.mytable')
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20024\1022962977.py in <module>
#       1 import pandas as pd
# ----> 2 pd.read_sql(engine,'SELECT * FROM public.mytable')
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     597     1           1  2010-11-12
#     598     """
# --> 599     pandas_sql = pandasSQL_builder(con)
#     600
#     601     if isinstance(pandas_sql, SQLiteDatabase):
#
# ~\anaconda3\envs\bootcamp\lib\site-packages\pandas\io\sql.py in pandasSQL_builder(con, schema, meta, is_cursor)
#     784     # When support for DBAPI connections is removed,
#     785     # is_cursor should not be necessary.
# --> 786     con = _engine_builder(con)
#     787     if _is_sqlalchemy_connectable(con):
# ...
